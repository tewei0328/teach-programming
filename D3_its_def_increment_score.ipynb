# %% [markdown]
# <a href="https://colab.research.google.com/github/tewei0328/teach-programming/blob/main/D3_its_def_increment_score.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 情況1:

# %%
def increment_score(score, bonus, points):
  if bonus == True:
    points = points * 2
    score = score + points
  return score

# %%
points = 5

# %%
score = 10

# %%
increment_score(score, True, points)
# Out:
# 20

# %%
new_score = increment_score(score, True, points)

# %%
print(new_score)
# Out:
# 20

# %% [markdown]
# ## 情況2: (請重新啟動工作階段)

# %%
def increment_score(score, bonus, points=1):
  if bonus == True:
    points = points * 2
    score = score + points
  return score

#points = 5
score = 10
new_score = increment_score(score, True, points)
print(new_score)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2419/1260597484.py in <cell line: 0>()
#       7 #points = 5
#       8 score = 10
# ----> 9 new_score = increment_score(score, True, points)
#      10 print(new_score)
#
# NameError: name 'points' is not defined

# %% [markdown]
# ## 情況3:(請重新啟動工作階段)

# %%
def increment_score(score, bonus, points=1):
  if bonus == True:
    points = points * 2
    score = score + points
  return score

#points = 5
score = 10
new_score = increment_score(score, True)
print(new_score)
# Out:
# 12
