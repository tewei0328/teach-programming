# %% [markdown]
# <a href="https://colab.research.google.com/github/tewei0328/teach-programming/blob/main/d2_%E5%AE%B9%E5%99%A8%E8%AE%8A%E6%95%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=1

# %%
type(a)
# Out:
# int

# %%
print(a)
# Out:
# 1

# %%
b='abc'

# %%
type(b)
# Out:
# str

# %%
print(b)
# Out:
# abc

# %%
c=input("請輸入變數c")
# Out:
# 請輸入變數cabcdefd

# %%
type(c)
# Out:
# str

# %%
print(c)
# Out:
# abcdefd

# %%
rooms = {1: 'Foyer', 2: 'Conference Room'}

# %%
type(rooms)
# Out:
# dict

# %%
print(rooms[2])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1587/2859354990.py in <cell line: 0>()
# ----> 1 print(rooms[2])
#
# KeyError: 2

# %%
rooms = {'1': 'Foyer', '2': 'Conference Room'}

# %%
rooms['1']
# Out:
# 'Foyer'

# %%
rooms = {1: 'Foyer', 2: 'Conference Room'}

# %%
room = int(input('Enter the room number: '))
# Out:
# Enter the room number: 2

# %%
room
# Out:
# 2

# %%
rooms[int(room)]
# Out:
# 'Conference Room'
