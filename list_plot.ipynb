# %% [markdown]
# <a href="https://colab.research.google.com/github/tewei0328/teach-programming/blob/main/list_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5]

# %%
plt.plot(x)

# %%
y=[i*i for i in x]

# %%
y
# Out:
# [1, 4, 9, 16, 25]

# %%
plt.plot(y)

# %%
plt.plot(x,y)

# %%
yy=[]
for z in x:
  yy.append(z*z)

# %%
yy
# Out:
# [1, 4, 9, 16, 25]
