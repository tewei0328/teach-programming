# %% [markdown]
# <a href="https://colab.research.google.com/github/tewei0328/teach-programming/blob/main/d1_%E8%AE%8A%E6%95%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=1

# %%
type(a)
# Out:
# int

# %%
b='abcd'

# %%
type(b)
# Out:
# str

# %%
c=True

# %%
type(c)
# Out:
# bool

# %%
d=1.23

# %%
type(d)
# Out:
# float
